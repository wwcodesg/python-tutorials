# %% [markdown]
# # Data Visualisation
# Import the modules:-

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Retrieve the data you created from ws1_Data_Cleaning.ipynb:

# %%
clean_path = "../../../data/3_clean/"
dfData = pd.read_csv(clean_path+'data.csv', index_col=[0,1])

# %%
dfData.head()
# Out:
#            Minimum Temperature  Mean Daily Rainfall Total  Mean Temperature  \
# Year Week
# 2012 1                    23.0                   1.860504         27.002632
#      2                    21.8                   3.473109         26.391453
#      3                    21.4                  12.357983         27.158772
#      4                    22.0                   1.522689         26.740000
#      5                    21.3                   7.144538         26.499160
#
#            Mean Wind Speed  Maximum Temperature  Max Wind Speed  Malaria  \
# Year Week
# 2012 1           11.973950                 32.9           114.1      1.0
#      2            8.773109                 33.7            64.8      2.0
#      3            6.971429                 34.6            60.8      2.0
#      4            9.651261                 33.2            51.8      3.0
#      5            9.527731                 32.8            65.5      1.0
#
#            Dengue
# Year Week
# 2012 1       74.0
#      2       66.0
#      3       61.0
#      4       52.0
#      5       85.0

# %% [markdown]
# # Simple lineplot

# %%
dfData.plot()

# %%
dfData.plot(figsize=(18.5, 10.5))

# %%
dfData.plot(subplots=True, figsize=(18.5,10.5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x116cbb160>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116d34240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116d43080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116dfd3c8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116e55860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116e55898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11e672048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11e6e6ba8>], dtype=object)

# %% [markdown]
# # box plot

# %%
dfData.boxplot(grid=True, figsize=(18.5,10.5))

# %% [markdown]
# ## investigate different data

# %%
dfData['Weekly Rainfall'] = dfData['Mean Daily Rainfall Total']*7

# %%
dfData[['Weekly Rainfall', 'Dengue', 'Malaria']].plot(subplots=True, figsize=(18.5,10.5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11f84d0b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11e646e10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11f913940>], dtype=object)

# %% [markdown]
# ## multiple bar plot

# %%
dfData[['Mean Temperature', 'Minimum Temperature', 'Maximum Temperature']].plot.bar()

# %% [markdown]
# # Build a plot in matplotlib

# %% [markdown]
# ### Set different colours of you choice:
# See
# https://matplotlib.org/api/colors_api.html
# and
# https://matplotlib.org/api/markers_api.html

# %%
colors = ['r', 'g', 'b', 'm','c','y']
markers = ['*', 's', 'p', '8','h','_']

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
for i, year in enumerate(range(2012, 2018)):
    denguef_year_data = dfData[dfData.index.get_level_values('Year')==year]
    plt.plot(denguef_year_data.index.get_level_values('Week'), denguef_year_data.Dengue, color = colors[i], marker = markers[i], label=str(year))
    plt.legend()
    plt.xlabel('Week number')
    plt.ylabel('Number of cases')
    plt.title('Dengue weekly trend')
